# %%
a_word = []
b_word = []
c_word = []
d_word = []

# %%
a_word = ['더럽게', '진짜', '다', '역겹다', '너무', '더럽다', '그', '안', '내가', '이', '좀', '내', '거', '구역질', '더럽고', '그냥', '수', '더', '왜', '근데', '아', '것', '나', '징그럽다', '하고', '하는', '나는', '있는', '정말', '잘', '한', '이런', '구역질이', '난', '게', '저', '그런', '존나', '또', '건', '아니', '못', '할', '뭐', '같은', '그리고', '그렇게', '기분', '네', '보고', '말', '이렇게', '많이', '걍', '없는', '흉측한', '제', '다시', '하', 'ㅋ', '너', '다른', '계속', '것도', '걸', '다들', '역겹고', '지금', '이제', '사람', '때', '무슨', '보면', '어떻게', '제가', '참', 'ㅋㅋ', '징그럽게', '날', '그래도', '오늘', '이거', '사람이', '자기', '와', '그래서', '이게', '더럽다고', '하지만', '그게', '아니라', '하나', '하면서', '듯', '나도', '같이', '한다', '손', '누가', '좋겠다', '일', '하면', '줄', '얼마나', '시발', '손을', '말을', '해', '그래', '얼굴', '모든', '제발', '우리', '자꾸', '역시', '더러운', '사실', '씨발', '번', '해도', '저는', '이미', '그거', '전', '징그럽고', '때문에', '그걸', '결국', 'ㅅㅂ', '먹고', '않고', '좋은', '하지', '있는데', '제일', '없다', '진심', '하는데', '둘', '있다', '꼭', '네가', '가장', '보는', '갑자기', '바로', '엄청', '그럼', '난다', '넌', '아주', '전에', '원래', '저런', '함', '개', '지', '것을', '눈', '입', '알고', '이건', '않는', '뭘', '막', 'ㅋㅋㅋ', '기분이', '해서', '구역질을', '나를', '어떤', '사람들', '사람들이', '말고', 'ㅠ', '일단', '아니면', '했는데', '없이', '위해', '야', 'ㅠㅠ', '생각', '두', '않은', '아니고', '없어서', '되는', '그건', '아무리', '것은', '것이', '혼자', '아닌', '뭔가', '약간', '거야', '중', '요즘', '자신의']

# %%
print(a_word)
# Out:
# ['더럽게', '진짜', '다', '역겹다', '너무', '더럽다', '그', '안', '내가', '이', '좀', '내', '거', '구역질', '더럽고', '그냥', '수', '더', '왜', '근데', '아', '것', '나', '징그럽다', '하고', '하는', '나는', '있는', '정말', '잘', '한', '이런', '구역질이', '난', '게', '저', '그런', '존나', '또', '건', '아니', '못', '할', '뭐', '같은', '그리고', '그렇게', '기분', '네', '보고', '말', '이렇게', '많이', '걍', '없는', '흉측한', '제', '다시', '하', 'ㅋ', '너', '다른', '계속', '것도', '걸', '다들', '역겹고', '지금', '이제', '사람', '때', '무슨', '보면', '어떻게', '제가', '참', 'ㅋㅋ', '징그럽게', '날', '그래도', '오늘', '이거', '사람이', '자기', '와', '그래서', '이게', '더럽다고', '하지만', '그게', '아니라', '하나', '하면서', '듯', '나도', '같이', '한다', '손', '누가', '좋겠다', '일', '하면', '줄', '얼마나', '시발', '손을', '말을', '해', '그래', '얼굴', '모든', '제발', '우리', '자꾸', '역시', '더러운', '사실', '씨발', '번', '해도', '저는', '이미', '그거', '전', '징그럽고', '때문에', '그걸', '결국', 'ㅅㅂ', '먹고', '않고', '좋은', '하지', '있는데', '제일', '없다', '진심', '하는데', '둘', '있다', '꼭', '네가', '가장', '보는', '갑자기', '바로', '엄청', '그럼', '난다', '넌', '아주', '전에', '원래', '저런', '함', '개', '지', '것을', '눈', '입', '알고', '이건', '않는', '뭘', '막', 'ㅋㅋㅋ', '기분이', '해서', '구역질을
# ...

# %%
b_word = ['웃음', '너무', '행복', '진짜', '그', '수', '행복을', '내', '웃음이', '것', '이', '더', '아', '웃음을', '내가', '다', '거', '나', '잘', '안', '하고', '보고', '오늘', '있는', '그냥', '한', '우리', '근데', '정말', '나는', '행복이', '저', '또', '네', '게', '하는', '좀', '많이', '그런', '지금', '난', '기쁨', '때', '그리고', 'ㅋ', '제', '행복만', '왜', '건', '할', '이런', '넘', '같이', '나의', '이렇게', '좋은', '다시', '하', '아니', '항상', '그렇게', '나도', '같은', '이제', '행복은', '없는', '함께', '제가', '네가', '즐거움', '못', '다른', '보면', '걸', '그래도', '모든', '이거', '계속', '사람', '하지만', '뭐', '신남', '것도', '이게', '하루', '꼭', '오늘도', '날', '해', '그래서', '말', '큰', '걍', '사랑해', '그럼', '행복한', '그게', '늘', 'ㅋㅋ', '사람이', '저는', '너', '생일', '듯', 'ㅠ', '당신의', 'ㅠㅠ', '어떻게', '즐거움을', '위해', '있어', '행복의', '많은', '갑자기', '저도', '너의', '기쁨을', '어떤', '볼', '하면서', '가장', '함박웃음', '일', '좋아', '웃는', '그래', '감사합니다', '눈', '헛웃음', '거야', '무슨', '줄', '중', '있어서', 'ㅋㅋㅋ', '사실', '조금', '말을', '언제나', '좋아하는', '바로', '혼자', '제일', '다들', '아니라', '같아요', '가득한', '역시', '나를', '보는', '있을', '덕분에', '웃음만', '임영웅', '같아', '하나', '고마워', '주는', '것이', '때문에', '있다', '행복해보여서', '전', '것을', '얼굴', '그저', '하면', '엄청', '해도', '없이', '될', '자꾸', '완전', '두', '자기', '아직', '행복과', '모두', '사랑', '이미', '그거', '같아서', '응', '아주', '결국', '번', '막', '보면서', '요즘', '작은', '참', '되는', 'ㅋㅋㅋㅋ', '나옴', '열심히', '것은', '너는', '얼마나', '와', '너무너무']

# %%
c_word=['다', '울', '너무', '진짜', '슬픔', '그', '것', '수', '내가', '더', '안', '거', '나', '울고', '근데', '이', '잘', '내', '그냥', '아', '좀', '하고', '애도', '또', '왜', '한', '나는', '있는', '보고', '때', '난', '게', '하는', '오늘', '저', '넘', '많이', '지금', '정말', '이렇게', '우리', '아니', '다들', '못', '그리고', '같이', '그런', '하', '이제', '울고싶다', '할', '슬픔을', '같은', '건', '다시', '이런', '그렇게', '없는', 'ㅋ', '나도', 'ㅠㅠ', '그래도', '걍', '계속', '네', '그래서', '제가', '다른', 'ㅠ', '하지만', '것도', '울지', '제', '걸', '사람이', '어떻게', '뭐', '좋겠다', '이거', '슬픔이', '듯', '말', '사실', '보면', '혼자', '갑자기', '꼭', '하면', '사람', '날', '같아요', '그럼', '눈물', 'ㅋㅋ', '좋은', '아니고', '저는', '네가', '모든', '너', '이게', '좋다', '조금', '같아서', '하면서', '울다', '때문에', '그게', '어려울', '얼마나', '엄청', '귀여울', '일', '정도로', '애들', '자기', '무슨', '줄', '하나', '막', '둘', '결국', '있는데', '거야', '해', '전', '함께', '와', '같아', '나를', '이미', '눈', '어떤', '같은데', '했는데', '있을', '그래', '있어', '역시', '제일', '존나', '저도', '보고싶다', '번', '항상', '아직', '바로', '있다', '해서', '완전', '말을', '울다가', '아니라', '귀엽다', '우는', '그거', '뭔가', '해도', '하는데', '없이', '슬픔에', '볼', '가장', '없어서', '같음', 'ㅋㅋㅋ', '제발', '많은', '일단', '있어서', '얼굴', '맨날', '두', '있음', '나의', '있고', '엉엉', '중', '요즘', '보면서', '큰', '수도', '보는', '누가', '것이', '열심히', '알고', '좋아', '그저', '눈물이', '않고', '참', '손', '함', '수가', '될', '자꾸', '않는', '좋아하는', '말고']

# %%
d_word = ['분노', '그', '분노가', '진짜', '이', '분노를', '수', '분노의', '너무', '다', '내가', '왜', '안', '것', '더', '근데', '내', '분노하고', '거', '그냥', '아', '하고', '대한', '나', '한', '하는', '나는', '좀', '있는', '또', '분노와', '분노에', '저', '지금', '그리고', '잘', '보고', '질투하고', '게', '아니', '그런', '때', '할', '분노로', '난', '시기하고', '없는', '이런', '정말', '분노는', '분노한', '분노하는', '같은', '시샘하고', '하', '다른', '오늘', '분개하고', '미워하고', '걍', '다시', '건', '그렇게', '이제', '못', '절망하고', '하지만', '모든', '갑자기', '어떻게', '그래서', '존나', '걸', '이렇게', 'ㅋ', '때문에', '보면', '아니라', '사람', '뭐', '이게', '씹새끼', '아파하고', '것도', '사람이', '이거', '제', '나도', '그게', '계속', '우리', '같이', 'ㅋㅋ', '네', '어떤', '결국', '자기', '많이', '날', '사실', '무슨', '위해', '듯', '나를', '중', '씨발', '못하고', '저는', '제가', '그래도', '하면서', '말', '있다', '분노도', '하면', '너', '있는데', '자신의', '전', '이미', '것을', '않는', '것이', '그럼', '화가', '같음', '나의', '것은', '않고', '다들', '가장', '하나', '그걸', '줄', '알고', '향한', '말을', '시발', '없이', '좋은', '혼자', '진심으로', '일', '네가', '되는', '바로', '없어', '감정을', '아니고', '와', '있음', '분노할', '함', '해', 'ㅋㅋㅋ', '그저', '역시', '하지', '번', '모두', '아닌', '거야', '해서', '아주', '저도', '그래', '슬픔', '슬퍼하고', '많은', '년', '하는데', '이건', '자꾸', '누가', '것에', '감정이', '사람들이', '사람을', '했는데', '개', '된', '일단', '넘', '없음', '돈', '그라데이션', '얼마나', '해도', '없다', '함께', '물론', '눈', '같아요', '일이', '있어', '새끼', '아직', '그거', '제일', '두']

# %%
e_word = a_word+d_word

# %%
print(e_word)
# Out:
# ['더럽게', '진짜', '다', '역겹다', '너무', '더럽다', '그', '안', '내가', '이', '좀', '내', '거', '구역질', '더럽고', '그냥', '수', '더', '왜', '근데', '아', '것', '나', '징그럽다', '하고', '하는', '나는', '있는', '정말', '잘', '한', '이런', '구역질이', '난', '게', '저', '그런', '존나', '또', '건', '아니', '못', '할', '뭐', '같은', '그리고', '그렇게', '기분', '네', '보고', '말', '이렇게', '많이', '걍', '없는', '흉측한', '제', '다시', '하', 'ㅋ', '너', '다른', '계속', '것도', '걸', '다들', '역겹고', '지금', '이제', '사람', '때', '무슨', '보면', '어떻게', '제가', '참', 'ㅋㅋ', '징그럽게', '날', '그래도', '오늘', '이거', '사람이', '자기', '와', '그래서', '이게', '더럽다고', '하지만', '그게', '아니라', '하나', '하면서', '듯', '나도', '같이', '한다', '손', '누가', '좋겠다', '일', '하면', '줄', '얼마나', '시발', '손을', '말을', '해', '그래', '얼굴', '모든', '제발', '우리', '자꾸', '역시', '더러운', '사실', '씨발', '번', '해도', '저는', '이미', '그거', '전', '징그럽고', '때문에', '그걸', '결국', 'ㅅㅂ', '먹고', '않고', '좋은', '하지', '있는데', '제일', '없다', '진심', '하는데', '둘', '있다', '꼭', '네가', '가장', '보는', '갑자기', '바로', '엄청', '그럼', '난다', '넌', '아주', '전에', '원래', '저런', '함', '개', '지', '것을', '눈', '입', '알고', '이건', '않는', '뭘', '막', 'ㅋㅋㅋ', '기분이', '해서', '구역질을
# ...

# %%
real_a = list(set(e_word)-set(b_word)-set(c_word))

# %%
print(real_a)
# Out:
# ['구역질', '더럽다고', '시샘하고', '진심', '것에', '기분', '약간', '더럽게', '원래', '새끼', '분노는', '물론', '아무리', '감정을', '향한', '분노하고', '징그럽게', '슬퍼하고', '아파하고', '분노를', '일이', '저런', '먹고', '미워하고', '기분이', '년', '화가', '그라데이션', '시발', '구역질이', '흉측한', '감정이', '구역질을', '더럽다', '더럽고', '돈', '사람들', '역겹고', '분노의', '절망하고', '이건', '분노', '분노한', '생각', '전에', '없어', '대한', '분노와', '그건', '시기하고', '손을', '아닌', '그걸', '분노로', '씹새끼', '된', '진심으로', '씨발', '질투하고', '사람을', '분노도', '없다', '않은', '넌', '분개하고', '분노가', '징그럽고', '분노에', '분노하는', '역겹다', '징그럽다', '없음', '자신의', '아니면', '사람들이', '야', '못하고', 'ㅅㅂ', '개', '입', '더러운', '뭘', '분노할', '난다', '지', '한다', '하지']

# %%
real_b = list(set(b_word)-set(c_word)-set(e_word))

# %%
print(real_b)
# Out:
# ['행복한', '즐거움', '기쁨', '하루', '행복과', '고마워', '당신의', '언제나', '덕분에', '응', '함박웃음', '기쁨을', '나옴', '행복만', '행복의', '너는', 'ㅋㅋㅋㅋ', '가득한', '늘', '사랑해', '감사합니다', '행복을', '웃는', '사랑', '생일', '행복이', '임영웅', '신남', '주는', '웃음', '웃음만', '작은', '행복해보여서', '너의', '너무너무', '헛웃음', '웃음을', '즐거움을', '오늘도', '행복은', '행복', '웃음이']

# %%
real_c = list(set(c_word)-set(b_word)-set(e_word))

# %%
print(real_c)
# Out:
# ['슬픔에', '슬픔이', '울다', '있고', '우는', '같은데', '울다가', '애도', '어려울', '귀엽다', '눈물이', '귀여울', '울지', '울', '좋다', '눈물', '울고', '보고싶다', '수도', '수가', '정도로', '맨날', '엉엉', '울고싶다', '슬픔을', '애들']

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
from matplotlib import rc
import pandas as pd 
import urllib.request
import numpy as np

# %%
sad_data = pd.read_csv("./data_sad.csv")
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\3834160462.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   sad_data = pd.read_csv("./data_sad.csv")

# %%
pleasure_data = pd.read_csv("./data_pleasure.csv")
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\2343989159.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   pleasure_data = pd.read_csv("./data_pleasure.csv")

# %%
sad_data['tweet'].nunique(), sad_data['id'].nunique()
# Out:
# (92767, 98260)

# %%
sad_data.drop_duplicates(subset=['tweet'], inplace=True)

# %%
print('총 샘플의 수 :',len(sad_data))
# Out:
# 총 샘플의 수 : 92767

# %%
sad_data['tweet'] = sad_data['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
sad_data[:5]['tweet']
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\927752442.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   sad_data['tweet'] = sad_data['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 0    아시발 진짜 평생 면상 안보고싶은데 굳이 기어와서 개귀찮게 지랄할거 생각하니깐 슬픔...
# 1    높은 자리가 성좌라면 그 발치를 맴도는 이는 어느 위치일까 사랑의 무게를 저울로 잰...
# 2    질질 흐르는 ㄱ멍보면서 차이사랑 차사장이  남자한테 박히는게 최적화되버렸다 우리들없...
# 3    사뭇 진지한 얼굴이었지만 여전히 장난스러운 얼굴울 했다 과장된 진지한 표정으로 턱을...
# 4               아 내일부터 전 혼자가 되겠군요  이렇게 많은 사람들과 절연해야한다니
# Name: tweet, dtype: object

# %%
sad_data['tweet'] = sad_data['tweet'].str.replace('^ +', "")
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\2652687377.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   sad_data['tweet'] = sad_data['tweet'].str.replace('^ +', "")

# %%
sad_data['tweet'].replace('', np.nan, inplace=True)
print(sad_data['tweet'].isnull().sum())
# Out:
# 270

# %%
sad_data = sad_data.dropna(subset=['tweet'])

# %%
print(len(sad_data))
# Out:
# 92497

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
token_count3 =dict()

# %%
for val in sad_data["tweet"]:

  # 문장을 string으로 만들기
  val = str(val)

  # 문장을 쪼개기
  tokens = val.split()
  for i in range(len(tokens)):
    if tokens[i] in token_count3.keys():
      token_count3[tokens[i]] +=1
    else:
      token_count3[tokens[i]] = 1
  #tokenized_text.append(tokens)

# %%
token_cnt_li3 = list(token_count3.items())

# %%
token_cnt_li3.sort(key=lambda x:x[1], reverse=True)

# %%
print(token_cnt_li3[:200])
# Out:
# [('다', 13081), ('울', 12080), ('너무', 11143), ('진짜', 9504), ('슬픔', 8012), ('그', 6199), ('것', 6001), ('수', 5686), ('내가', 5335), ('더', 5178), ('안', 5100), ('거', 5003), ('나', 4973), ('울고', 4713), ('근데', 4514), ('이', 4277), ('잘', 4214), ('내', 3870), ('그냥', 3749), ('아', 3684), ('좀', 3603), ('하고', 3524), ('애도', 3371), ('또', 3043), ('왜', 2971), ('한', 2937), ('나는', 2861), ('있는', 2858), ('보고', 2628), ('때', 2568), ('난', 2541), ('게', 2515), ('하는', 2492), ('오늘', 2491), ('저', 2473), ('넘', 2382), ('많이', 2346), ('지금', 2316), ('정말', 2303), ('이렇게', 2287), ('우리', 2251), ('아니', 2184), ('다들', 2160), ('못', 2141), ('그리고', 2119), ('같이', 2114), ('그런', 2072), ('하', 2058), ('이제', 2046), ('울고싶다', 1958), ('할', 1958), ('슬픔을', 1907), ('같은', 1887), ('건', 1859), ('다시', 1858), ('이런', 1844), ('그렇게', 1783), ('없는', 1754), ('ㅋ', 1745), ('나도', 1671), ('ㅠㅠ', 1631), ('그래도', 1573), ('걍', 1566), ('계속', 1509), ('네', 1494), ('그래서', 1486), ('제가', 1447), ('다른', 1437), ('ㅠ', 1414), ('하지만', 1412), ('것도', 1379), ('울지', 1360), ('제', 1
# ...

# %%
sad_word = []

# %%
for i in range(400):
    sad_word.append(token_cnt_li3[i][0])

# %%
pleasure_data['tweet'].nunique(), pleasure_data['id'].nunique()
# Out:
# (92318, 100006)

# %%
pleasure_data.drop_duplicates(subset=['tweet'], inplace=True)

# %%
print('총 샘플의 수 :',len(pleasure_data))
# Out:
# 총 샘플의 수 : 92318

# %%
pleasure_data['tweet'] = pleasure_data['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
pleasure_data[:5]['tweet']
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\253384315.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   pleasure_data['tweet'] = pleasure_data['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 0          아 씨발 개처웃음 존나 웃김 캐해 레전드다
# 1               갤러리 보다가 갑자기 보고 개웃음
# 2
# 3    바밍 라이브 너무 신남 한국에서 라이브 좀 자주 해라
# 4              그대는 늘 행복의 한복판에 있길
# Name: tweet, dtype: object

# %%
pleasure_data['tweet'] = pleasure_data['tweet'].str.replace('^ +', "")
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\2685867287.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   pleasure_data['tweet'] = pleasure_data['tweet'].str.replace('^ +', "")

# %%
pleasure_data['tweet'].replace('', np.nan, inplace=True)
print(pleasure_data['tweet'].isnull().sum())
# Out:
# 2442

# %%
pleasure_data = pleasure_data.dropna(subset=['tweet'])

# %%
print(len(pleasure_data))
# Out:
# 89876

# %%
token_count4 =dict()

# %%
for val in pleasure_data["tweet"]:

  # 문장을 string으로 만들기
  val = str(val)

  # 문장을 쪼개기
  tokens = val.split()
  for i in range(len(tokens)):
    if tokens[i] in token_count4.keys():
      token_count4[tokens[i]] +=1
    else:
      token_count4[tokens[i]] = 1
  #tokenized_text.append(tokens)

# %%
token_cnt_li4 = list(token_count4.items())

# %%
token_cnt_li4.sort(key=lambda x:x[1], reverse=True)

# %%
print(token_cnt_li4[:200])
# Out:
# [('웃음', 11725), ('너무', 8417), ('행복', 7689), ('진짜', 6157), ('그', 5524), ('수', 5373), ('행복을', 4714), ('내', 4647), ('웃음이', 4128), ('것', 3929), ('이', 3887), ('더', 3849), ('아', 3799), ('웃음을', 3775), ('내가', 3733), ('다', 3512), ('거', 3447), ('나', 3188), ('잘', 3132), ('안', 3056), ('하고', 2756), ('보고', 2549), ('오늘', 2537), ('있는', 2531), ('그냥', 2457), ('한', 2375), ('우리', 2362), ('근데', 2306), ('정말', 2292), ('나는', 2291), ('행복이', 2280), ('저', 2259), ('또', 2141), ('네', 2129), ('게', 2012), ('하는', 1987), ('좀', 1945), ('많이', 1904), ('그런', 1874), ('지금', 1851), ('난', 1789), ('기쁨', 1777), ('때', 1756), ('그리고', 1728), ('ㅋ', 1677), ('제', 1675), ('행복만', 1672), ('왜', 1670), ('건', 1641), ('할', 1641), ('이런', 1622), ('넘', 1597), ('같이', 1583), ('나의', 1573), ('이렇게', 1572), ('좋은', 1567), ('다시', 1564), ('하', 1512), ('아니', 1501), ('항상', 1493), ('그렇게', 1415), ('나도', 1393), ('같은', 1381), ('이제', 1313), ('행복은', 1265), ('없는', 1256), ('함께', 1228), ('제가', 1214), ('네가', 1190), ('즐거움', 1186), ('못', 1183), ('다른', 1179), ('보면',
# ...

# %%
pleasure_word = []

# %%
for i in range(400):
    pleasure_word.append(token_cnt_li4[i][0])

# %%
print(e_word, len(e_word))
# Out:
# ['더럽게', '진짜', '다', '역겹다', '너무', '더럽다', '그', '안', '내가', '이', '좀', '내', '거', '구역질', '더럽고', '그냥', '수', '더', '왜', '근데', '아', '것', '나', '징그럽다', '하고', '하는', '나는', '있는', '정말', '잘', '한', '이런', '구역질이', '난', '게', '저', '그런', '존나', '또', '건', '아니', '못', '할', '뭐', '같은', '그리고', '그렇게', '기분', '네', '보고', '말', '이렇게', '많이', '걍', '없는', '흉측한', '제', '다시', '하', 'ㅋ', '너', '다른', '계속', '것도', '걸', '다들', '역겹고', '지금', '이제', '사람', '때', '무슨', '보면', '어떻게', '제가', '참', 'ㅋㅋ', '징그럽게', '날', '그래도', '오늘', '이거', '사람이', '자기', '와', '그래서', '이게', '더럽다고', '하지만', '그게', '아니라', '하나', '하면서', '듯', '나도', '같이', '한다', '손', '누가', '좋겠다', '일', '하면', '줄', '얼마나', '시발', '손을', '말을', '해', '그래', '얼굴', '모든', '제발', '우리', '자꾸', '역시', '더러운', '사실', '씨발', '번', '해도', '저는', '이미', '그거', '전', '징그럽고', '때문에', '그걸', '결국', 'ㅅㅂ', '먹고', '않고', '좋은', '하지', '있는데', '제일', '없다', '진심', '하는데', '둘', '있다', '꼭', '네가', '가장', '보는', '갑자기', '바로', '엄청', '그럼', '난다', '넌', '아주', '전에', '원래', '저런', '함', '개', '지', '것을', '눈', '입', '알고', '이건', '않는', '뭘', '막', 'ㅋㅋㅋ', '기분이', '해서', '구역질을
# ...

# %%
print(pleasure_word, len(pleasure_word))
# Out:
# ['웃음', '너무', '행복', '진짜', '그', '수', '행복을', '내', '웃음이', '것', '이', '더', '아', '웃음을', '내가', '다', '거', '나', '잘', '안', '하고', '보고', '오늘', '있는', '그냥', '한', '우리', '근데', '정말', '나는', '행복이', '저', '또', '네', '게', '하는', '좀', '많이', '그런', '지금', '난', '기쁨', '때', '그리고', 'ㅋ', '제', '행복만', '왜', '건', '할', '이런', '넘', '같이', '나의', '이렇게', '좋은', '다시', '하', '아니', '항상', '그렇게', '나도', '같은', '이제', '행복은', '없는', '함께', '제가', '네가', '즐거움', '못', '다른', '보면', '걸', '그래도', '모든', '이거', '계속', '사람', '하지만', '뭐', '신남', '것도', '이게', '하루', '꼭', '오늘도', '날', '해', '그래서', '말', '큰', '걍', '사랑해', '그럼', '행복한', '그게', '늘', 'ㅋㅋ', '사람이', '저는', '너', '생일', '듯', 'ㅠ', '당신의', 'ㅠㅠ', '어떻게', '즐거움을', '위해', '있어', '행복의', '많은', '갑자기', '저도', '너의', '기쁨을', '어떤', '볼', '하면서', '가장', '함박웃음', '일', '좋아', '웃는', '그래', '감사합니다', '눈', '헛웃음', '거야', '무슨', '줄', '중', '있어서', 'ㅋㅋㅋ', '사실', '조금', '말을', '언제나', '좋아하는', '바로', '혼자', '제일', '다들', '아니라', '같아요', '가득한', '역시', '나를', '보는', '있을', '덕분에', '웃음만', '임영웅', '같아', '하나', '고마워', '주는', '것이', '때문에', '있다', '행복해보여서', '전', '것을', '얼굴', '그저',
# ...

# %%
print(sad_word, len(sad_word))
# Out:
# ['다', '울', '너무', '진짜', '슬픔', '그', '것', '수', '내가', '더', '안', '거', '나', '울고', '근데', '이', '잘', '내', '그냥', '아', '좀', '하고', '애도', '또', '왜', '한', '나는', '있는', '보고', '때', '난', '게', '하는', '오늘', '저', '넘', '많이', '지금', '정말', '이렇게', '우리', '아니', '다들', '못', '그리고', '같이', '그런', '하', '이제', '울고싶다', '할', '슬픔을', '같은', '건', '다시', '이런', '그렇게', '없는', 'ㅋ', '나도', 'ㅠㅠ', '그래도', '걍', '계속', '네', '그래서', '제가', '다른', 'ㅠ', '하지만', '것도', '울지', '제', '걸', '사람이', '어떻게', '뭐', '좋겠다', '이거', '슬픔이', '듯', '말', '사실', '보면', '혼자', '갑자기', '꼭', '하면', '사람', '날', '같아요', '그럼', '눈물', 'ㅋㅋ', '좋은', '아니고', '저는', '네가', '모든', '너', '이게', '좋다', '조금', '같아서', '하면서', '울다', '때문에', '그게', '어려울', '얼마나', '엄청', '귀여울', '일', '정도로', '애들', '자기', '무슨', '줄', '하나', '막', '둘', '결국', '있는데', '거야', '해', '전', '함께', '와', '같아', '나를', '이미', '눈', '어떤', '같은데', '했는데', '있을', '그래', '있어', '역시', '제일', '존나', '저도', '보고싶다', '번', '항상', '아직', '바로', '있다', '해서', '완전', '말을', '울다가', '아니라', '귀엽다', '우는', '그거', '뭔가', '해도', '하는데', '없이', '슬픔에', '볼', '가장', '없어서', '같음', 'ㅋㅋㅋ', '제발', '많은', '일
# ...

# %%
word_1 = list(set(pleasure_word)-set(sad_word)-set(e_word))

# %%
print(word_1)
# Out:
# ['나오는', '즐거움', '삐짐', '웃음은', '하하', '볼때마다', '웃음으로', '나와', '느끼는', '당신', '뭐야', '행복이', '네이버', '웃음', '소소한', '원망', '오랜만에', '평생', '개저웃음', '행복은', '행복', '작게', '내게', '행복과', '고마워', '기쁨을', '행복도', '영원한차일드우리마크생일축하해', '웃음기', '행복을', '사랑', '생일', '말에', '당신은', '있다는', '주는', '표정', '웃음도', '축하해', '나에게', '보며', '사랑을', '화남', '임영웅', '좋겠어', '즐거움을', '순간', '짓고', '기쁨', '행복회로', '출처', '나옴', '행복만', '행복의', '평소', '가득한', '우리가', '행복에', '즐거움이', '잘못', '위한', '고개', '봐도', '귀여운', 'ㅋㅋㅋㅋㅋㅋ', '웃음을', '웃음에', '예쁜', '우리의', '이찬원', '행복해', '웃음이', '소중한', '있습니다', '잠시', '세상', '함박웃음', '형', '음', '첫', '영상', '새로운', '돼', '있다면', '신남', '짓는', '기쁨의', '행복하게', '웃음만', '가득', '봐', '여전히', '행복해보여서', '앞으로도', '크게', '당신을', '행복으로', '기쁨이', '헛웃음', '귀여워서', '부탁']

# %%
word_1.remove('영원한차일드우리마크생일축하해')
word_1.remove('이찬원')
word_1.remove('네이버')
word_1.remove('임영웅')

# %%
for i in range(len(word_1)):
    if len(word_1[i]) == 1:
        word_1.remove(word_1[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [130], in <cell line: 1>()
#       1 for i in range(len(word_1)):
# ----> 2     if len(word_1[i]) == 1:
#       3         word_1.remove(word_1[i])
#
# IndexError: list index out of range

# %%
 print(word_1[90],len(word_1[90]))
# Out:
# 헛웃음 3

# %%
print(word_1, len(word_1))
# Out:
# ['나오는', '즐거움', '삐짐', '웃음은', '하하', '볼때마다', '웃음으로', '나와', '느끼는', '당신', '뭐야', '행복이', '웃음', '소소한', '원망', '오랜만에', '평생', '개저웃음', '행복은', '행복', '작게', '내게', '행복과', '고마워', '기쁨을', '행복도', '웃음기', '행복을', '사랑', '생일', '말에', '당신은', '있다는', '주는', '표정', '웃음도', '축하해', '나에게', '보며', '사랑을', '화남', '좋겠어', '즐거움을', '순간', '짓고', '기쁨', '행복회로', '출처', '나옴', '행복만', '행복의', '평소', '가득한', '우리가', '행복에', '즐거움이', '잘못', '위한', '고개', '봐도', '귀여운', 'ㅋㅋㅋㅋㅋㅋ', '웃음을', '웃음에', '예쁜', '우리의', '행복해', '웃음이', '소중한', '있습니다', '잠시', '세상', '함박웃음', '음', '영상', '새로운', '있다면', '신남', '짓는', '기쁨의', '행복하게', '웃음만', '가득', '여전히', '행복해보여서', '앞으로도', '크게', '당신을', '행복으로', '기쁨이', '헛웃음', '귀여워서', '부탁'] 93

# %%
word_2 = list(set(sad_word)-set(pleasure_word)-set(e_word))

# %%
for i in range(len(word_2)):
    if len(word_2[i]) == 1:
        word_2.remove(word_2[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [134], in <cell line: 1>()
#       1 for i in range(len(word_2)):
# ----> 2     if len(word_2[i]) == 1:
#       3         word_2.remove(word_2[i])
#
# IndexError: list index out of range

# %%
print(word_2, len(word_2))
# Out:
# ['여기', '아쉬울', '그러다', '울다가', '아마', '이러고', '냅다', '마음을', '귀여울', '시간이', '나한테', '울지마', '이젠', '된다', '애가', '그대로', '없는데', '울어', '같고', '자기가', '되게', '슬픔에', '울기', '싶은데', '슬픔이', '거의', '했다', 'ㅠㅠㅠ', '어려울', '아무도', '밖에', '아닌데', '솔직히', '보고싶다', '수가', '정도로', '가서', '울고싶다', '생각을', '언니', '저렇게', '엄마', '울다', '우는', '집에', '둘다', '오히려', '있었다', '이번', '슬픔의', '모르는', '같다', '슬픔은', '가는', '아니야', '울고', '아님', '제대로', '슬픔을', '앞에서', '애들', '싶다', '그때', '울게', '애도', '슬픔과', '싶어서', '귀엽다', '보니까', '눈물을', '눈물이', '울지', '내일', '슬픔도', '아니다', '울겠다', 'ㄹㅇ', '무서울', '와서', '그러면', '없고', '지금은', '아무것도', '엉엉', '나랑', '애기'] 86

# %%
word_3 = list(set(e_word)-set(pleasure_word)-set(sad_word))

# %%
for i in range(len(word_3)):
    if len(word_3[i]) == 1:
        word_3.remove(word_3[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [137], in <cell line: 1>()
#       1 for i in range(len(word_3)):
# ----> 2     if len(word_3[i]) == 1:
#       3         word_3.remove(word_3[i])
#
# IndexError: list index out of range

# %%
print(word_3, len(word_3))
# Out:
# ['저런', '분노하는', '역겹다', '미워하고', '분노와', '시기하고', '구역질', '징그럽다', '더럽다고', '시샘하고', '그라데이션', '화가', '분노로', '씹새끼', '시발', '구역질이', '흉측한', '감정이', '구역질을', '것에', '더럽다', '더럽게', '더럽고', '새끼', '분노는', '씨발', '질투하고', '분노도', '감정을', '역겹고', '향한', '분노의', '더러운', '분노하고', '징그럽게', '분개하고', '절망하고', '분노', '분노한', '슬퍼하고', '분노할', '아파하고', '난다', '분노를', '분노가', '징그럽고', '분노에'] 47

# %%
AA = pd.read_csv("./for_pleasure.csv")

# %%
AA['tweet'].nunique()
# Out:
# 92255

# %%
AA.drop_duplicates(subset=['tweet'], inplace=True)

# %%
AA['tweet'] = AA['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
AA[:5]['tweet']
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\1357369971.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   AA['tweet'] = AA['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 0                              아 씨발 개처웃음 존나 웃김 캐해 레전드다
# 1                                   갤러리 보다가 갑자기 보고 개웃음
# 3                        바밍 라이브 너무 신남 한국에서 라이브 좀 자주 해라
# 4                                  그대는 늘 행복의 한복판에 있길
# 5    인문학을 한다는 자부심 연구하고 싶은 주제에 매달리는 기쁨 등이 내 삶의 추진력이다...
# Name: tweet, dtype: object

# %%
AA['tweet'] = AA['tweet'].str.replace('^ +', "")
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\2449588000.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   AA['tweet'] = AA['tweet'].str.replace('^ +', "")

# %%
AA['tweet'].replace('', np.nan, inplace=True)
print(AA['tweet'].isnull().sum())
# Out:
# 0

# %%
AA = AA.dropna(subset=['tweet'])

# %%
print(len(AA))
# Out:
# 89812

# %%
AA['new_label1'] = np.nan
AA['new_label2'] = np.nan
AA['new_label3'] = np.nan

# %%
for val in AA['tweet']:
    check_1 = 0
    check_2 = 0
    check_3 = 0
    new_check_1 = 0
    new_check_2 = 0
    new_check_3 = 0
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        if tokens[i] in word_1:
            check_1 +=1
        elif tokens[i] in word_2:
            check_2 +=1
        elif tokens[i] in word_3:
            check_3 +=1
    for k in range(len(word_1)):
        new_check_1 += val.count(word_1[k])
    for j in range(len(word_2)):
        new_check_2 += val.count(word_2[j])
    for m in range(len(word_3)):
        new_check_3 += val.count(word_3[m])
        
    AA.loc[AA['tweet']==val, 'label1'] = check_1
    AA.loc[AA['tweet']==val, 'label2'] = check_2
    AA.loc[AA['tweet']==val, 'label3'] = check_3
    AA.loc[AA['tweet']==val, 'new_label1'] = new_check_1
    AA.loc[AA['tweet']==val, 'new_label2'] = new_check_2
    AA.loc[AA['tweet']==val, 'new_label3'] = new_check_3

# %%
AA.to_csv('./dAAb.csv', index=False, encoding="utf-8-sig")

# %%
print(AA[100:120])
# Out:
#                                                  tweet  label1  label2  \
# 103                                 오 교환 찾았어 오메데토ㅠㅠㅠㅠㅠ     0.0     0.0
# 104               비상사태 제가씹뜨억웃음 짓다가 빨간마스크가 될 것 같난 소식입니다     0.0     0.0
# 105                                                 히키     0.0     0.0
# 106                   오늘 진짜 우울했는데 소시 보고 웃음 ㅠㅠ 고마워요 갓소시     1.0     0.0
# 107  소녀때 소름돋는 그 웃음 내내 다 좋은데  한나 뛰어 들어와서 손뻗을때 사람들 사이...     1.0     0.0
# 108                                               뭐하세요     0.0     0.0
# 109  이 분 진짜 웃긴 분이에요 아니 갑자기 웃음 터져서진짜 별안간 찬니진도  이러고 웃...     1.0     1.0
# 110                                  아 오늘 최고로웃음 ㅋㅋㅋㅋㅋㅋ     1.0     0.0
# 111                                    행복이이잉 너무 너무 기여버     0.0     0.0
# 112                                         자살말림 이래서씨발     0.0     0.0
# 113                              사랑해 내 행복둥이  더보이즈 선우       0.0     0.0
# 114  감염인으로 살기  느껴져야 할 행복이 불쑥 질문으로 날아들 때가 있다 몸 하나 편히...     1.0     0.0
# ...

# %%
BB = pd.read_csv("./for_sad.csv")

# %%
BB['tweet'].nunique()
# Out:
# 92686

# %%
BB.drop_duplicates(subset=['tweet'], inplace=True)

# %%
BB['tweet'] = BB['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
BB[:5]['tweet']
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\226667674.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   BB['tweet'] = BB['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 0    아시발 진짜 평생 면상 안보고싶은데 굳이 기어와서 개귀찮게 지랄할거 생각하니깐 슬픔...
# 1    높은 자리가 성좌라면 그 발치를 맴도는 이는 어느 위치일까 사랑의 무게를 저울로 잰...
# 2    질질 흐르는 ㄱ멍보면서 차이사랑 차사장이  남자한테 박히는게 최적화되버렸다 우리들없...
# 3    사뭇 진지한 얼굴이었지만 여전히 장난스러운 얼굴울 했다 과장된 진지한 표정으로 턱을...
# 4               아 내일부터 전 혼자가 되겠군요  이렇게 많은 사람들과 절연해야한다니
# Name: tweet, dtype: object

# %%
BB['tweet'] = BB['tweet'].str.replace('^ +', "")
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\2014235451.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   BB['tweet'] = BB['tweet'].str.replace('^ +', "")

# %%
BB['new_label2'] = np.nan
BB['new_label3'] = np.nan

# %%
for val in BB['tweet']:
    check_1 = 0
    check_2 = 0
    check_3 = 0
    new_check_1 = 0
    new_check_2 = 0
    new_check_3 = 0
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        if tokens[i] in word_1:
            check_1 +=1
        elif tokens[i] in word_2:
            check_2 +=1
        elif tokens[i] in word_3:
            check_3 +=1
    for k in range(len(word_1)):
        new_check_1 += val.count(word_1[k])
    for j in range(len(word_2)):
        new_check_2 += val.count(word_2[j])
    for m in range(len(word_3)):
        new_check_3 += val.count(word_3[m])
        
    BB.loc[BB['tweet']==val, 'label1'] = check_1
    BB.loc[BB['tweet']==val, 'label2'] = check_2
    BB.loc[BB['tweet']==val, 'label3'] = check_3
    BB.loc[BB['tweet']==val, 'new_label1'] = new_check_1
    BB.loc[BB['tweet']==val, 'new_label2'] = new_check_2
    BB.loc[BB['tweet']==val, 'new_label3'] = new_check_3

# %%
print(BB[100:120])
# Out:
#                                                  tweet  label1  label2  \
# 100  문대씨 내가 지금 무슨 말을  그제야 핸드폰 바로 켜들고 문자 전화 문대한테 우다다...     0.0     1.0
# 101  오늘 간만에 마살이랑 디코했는데년동안 하컨 안간거면 절컨 너무 그리울 시기래 그래그...     0.0     0.0
# 102  실트 이제봄 나도 에테르 파티린가이아울부짖고싶다내가 에덴을 왜 사랑하는데 크허어어어...     0.0     0.0
# 103  네가 죽는 걸 무력하게 지켜만 보는 건 얼마나 무서울까 네가 조금만 다쳐도 마음이 ...     0.0     1.0
# 104  하 친애도 친애작이라는 단어를 모를때로 돌아갈수가없음 많은 오타쿠 언어생활을 여기 ...     0.0     1.0
# 105  렌 님이 몇번이고 그녀의 머리체를 휘어잡고 바닥에 쳐박았다목을 그으셨다간신히 구해져...     1.0     0.0
# 106     현생ㅇ땜에 애들이랑 재밋는거할기회 다놓친거갓아서 넘슬픔    히발나랑놀아줘어어어어어     0.0     0.0
# 107  그러나 그런 얼굴을 이미 몇 번이나 봐서 어느 정도 익숙해져 있었음에도 아까 보여줬...     1.0     2.0
# 108  나떤여자 만날수있지 둘이 잘 어울림 잘통하는거같음 뭐 스킨십 할수있지 어린애도아니고...     0.0     1.0
# 109                                           길면무섭네요슬픔     0.0     0.0
# 110  가만히 갸웃거리던 민지호 오너 지금 무서워서 덜덜 떠는 중 하 어떻게 말 꺼내나요 ...     0.0     0.0
# 111  그건 그렇고 그 때나 이제나 나는 억억대며 울지 못한다 사실이 나를 수치스럽게 한다...     0.0     1.0
# ...

# %%
BB.to_csv('./dBBb.csv', index=False, encoding="utf-8-sig")

# %%
import pandas as pd
CC = pd.read_csv("./for_anger.csv", encoding="cp949")

# %%
print(CC)
# Out:
#                                                    tweet  label1  label2  \
# 0      억지력으로 남게해달라고요 미친새끼등라 작별도 제대로못하고 이렇게 사라진다고? 이게말...     NaN     NaN
# 1      쪼마랴 노선 너무너무 즐거웠음… 분노 가득하고 아버지와 참 닮은 쪼마랴  그리고 다...     NaN     NaN
# 2      분노가 자신을 향할 때 우울이 된다. 우울한 사람은 사실 분노하고 있는 것이다. 왜...     NaN     NaN
# 3      이집트가 中 전투기 써본후 격노해 FA-50 '역대급' 전면교체 선포한 충격 상황 ...     NaN     NaN
# 4      데연시해봤는데 번역의한계인진몰라도 존나그냥 몰입안돼 근데 제작진도 장난치면서 만든게...     NaN     NaN
# ...                                                  ...     ...     ...
# 25340  그냥 하던대로. 사랑이나 하고싶다고 (덕질하고싶다는뜻. 헤테로간 교미x) 전방에 분...     NaN     NaN
# 25341  야 미친새끼야 니는 의사한테 전화해야할거아니야 이씹!!!! 야!!!! 그게 사랑이야...     NaN     NaN
# 25342  콘서트 코앞에 두고 얼마나 경계심 없이 싸돌아댕겼으면 ㅉㅉ 정작 욕쳐먹어야될 새끼는...     NaN     NaN
# 25343  근데진짜 약간... 2차에서보단 키리+바쿠는 키리시마가 더 시끄러웠는데 원작보니까 ...     NaN     NaN
# 25344  @maga_catus 이 일을 아주 오래오래 생각하면서 화내야겠다고  맘먹었지만 현...     NaN     NaN
#
#        label3  new_label1  new_label2  new_label3
# ...

# %%
CC['tweet'].nunique()
# Out:
# 24083

# %%
CC.drop_duplicates(subset=['tweet'], inplace=True)

# %%
CC['tweet'] = CC['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
CC[:5]['tweet']
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\495858133.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   CC['tweet'] = CC['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 0    억지력으로 남게해달라고요 미친새끼등라 작별도 제대로못하고 이렇게 사라진다고 이게말이...
# 1    쪼마랴 노선 너무너무 즐거웠음 분노 가득하고 아버지와 참 닮은 쪼마랴  그리고 다시...
# 2    분노가 자신을 향할 때 우울이 된다 우울한 사람은 사실 분노하고 있는 것이다 왜 누...
# 3          이집트가  전투기 써본후 격노해  역대급 전면교체 선포한 충격 상황   출처
# 4    데연시해봤는데 번역의한계인진몰라도 존나그냥 몰입안돼 근데 제작진도 장난치면서 만든게...
# Name: tweet, dtype: object

# %%
CC['tweet'] = CC['tweet'].str.replace('^ +', "")
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\3518488910.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   CC['tweet'] = CC['tweet'].str.replace('^ +', "")

# %%
CC['tweet'].replace('', np.nan, inplace=True)
print(CC['tweet'].isnull().sum())
# Out:
# 355

# %%
CC = CC.dropna(subset=['tweet'])

# %%
print(len(CC))
# Out:
# 23728

# %%
for val in CC['tweet']:
    check_1 = 0
    check_2 = 0
    check_3 = 0
    new_check_1 = 0
    new_check_2 = 0
    new_check_3 = 0
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        if tokens[i] in word_1:
            check_1 +=1
        elif tokens[i] in word_2:
            check_2 +=1
        elif tokens[i] in word_3:
            check_3 +=1
    for k in range(len(word_1)):
        new_check_1 += val.count(word_1[k])
    for j in range(len(word_2)):
        new_check_2 += val.count(word_2[j])
    for m in range(len(word_3)):
        new_check_3 += val.count(word_3[m])
        
    CC.loc[CC['tweet']==val, 'label1'] = check_1
    CC.loc[CC['tweet']==val, 'label2'] = check_2
    CC.loc[CC['tweet']==val, 'label3'] = check_3
    CC.loc[CC['tweet']==val, 'new_label1'] = new_check_1
    CC.loc[CC['tweet']==val, 'new_label2'] = new_check_2
    CC.loc[CC['tweet']==val, 'new_label3'] = new_check_3

# %%
print(CC[100:120])
# Out:
#                                                  tweet  label1  label2  \
# 100  이여자는 먼생각으로 올콘을 내려놓앗을까 왜 첫콘만 가기로 한 걸까 앞으로 시간남았는...     0.0     1.0
# 101  아나그것도 뱅기타고 가는 그 시간에 이걸 올린다는 게 넘나얼탱이네여아침에 일어나면 ...     0.0     1.0
# 102  넬삐를 보면 짜식들 예쁜사랑해라 하면서도 나를 남동생처럼 줘패준 우리누나가 놈팽이애...     0.0     0.0
# 103  키파 공 확인하면서 또흐무드가 카림한테 총 겨눌 때 눈빛은 분노와 공허함 슬픔 와중...     0.0     0.0
# 104  선글라스 벗은 눈이 날 것 그대로의 분노를 마주하는 것이라면 느낄 수 있는 것에 가...     0.0     0.0
# 105  잘못 감기면 큰일나는데두요잘못 걸린 사람  지금 얘한테 의식주 제공했던 모브 틀라 ...     1.0     0.0
# 106  아니 나 연초에 생일이라고 친구랑 동생들이랑 술 존나 처먹고 담배 존나 펴서 편도선...     0.0     0.0
# 107  하 밥짓기물론전기밥솥이다합니다년차여성 개같이분노 색깔에서분노하는거아님 색깔은나도맘에...     0.0     0.0
# 108                                           분노게이지 상승     0.0     0.0
# 109  그것을 깨달은 나는 분노했다 신을 저주했어 이 지옥에서 이 아름다운 이들을 이토록 ...     0.0     0.0
# 110                                    뭐래 이 씹헨타이 게이새끼가     0.0     0.0
# 111  죽을 각오속에서 활로를 찾았다는건가 그렇더라도 넌 내게서 이길 수 없다 힘이 강해졌...     0.0     0.0
# ...

# %%
CC.to_csv('./dCCb.csv', index=False, encoding="utf-8-sig")

# %%
DD = pd.read_csv("./for_aversion.csv")

# %%
print(DD)
# Out:
#                                                   tweet  label1  label2  \
# 0     대부분 사람들은 나에게 소리를 지르거나 막대기를 휘두르거나 한다. 나는 더럽기 때문...     NaN     NaN
# 1     귀관이 구역질로 중대가를 연주할 실력이 된다면 모를까, 그렇지 않은 바에야 작업 방해다.     NaN     NaN
# 2     @mmmilk0729 아ㅠ ㅠ ㅠ ㅋㅋㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 은하 그냥 눈치껏 그랬나...     NaN     NaN
# 3     형이랑 이러는 것도 이제 구역질나서 못해먹겠다 우리 그냥 각자 갈길 가요 다이아 반...     NaN     NaN
# 4     오늘 일반 돌리는데 상대팀 자꾸 저지 들고 게임 더럽게 하길래 우리팀은 오딘 들고 ...     NaN     NaN
# ...                                                 ...     ...     ...
# 8342  내자리만 엉망진창 존나더럽내 그치만 다 필요한것들이라 정리할려면 며칠은 걸리고 파ㅡ...     NaN     NaN
# 8343  불꽃처럼 타오르는 청춘🎶  넌나의 실험대상~난너의 창조주~  이그림이~~날대신해~~...     NaN     NaN
# 8344  페북 진짜 역겹고 싫음.. 지들 멋대로 다 불펌해가고 지글이 마냥 다 찾은 거 처럼...     NaN     NaN
# 8345  아까부터 징그럽다 했는데 이게 무슨..! 이렇게 생각하고 왜..왜 이러는 거야 해리...     NaN     NaN
# 8346  @99sang_ar 에~ 마지? 그 더러운걸 귀엽게 보셨다구요? 저는요.. 정말 너...     NaN     NaN
#
#       label3  new_label1  new_label2  new_label3
# 0        NaN         NaN         NaN         NaN
# ...

# %%
DD['tweet'].nunique()
# Out:
# 7732

# %%
DD.drop_duplicates(subset=['tweet'], inplace=True)

# %%
DD['tweet'] = DD['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
DD[:5]['tweet']
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\1467707243.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   DD['tweet'] = DD['tweet'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 0    대부분 사람들은 나에게 소리를 지르거나 막대기를 휘두르거나 한다 나는 더럽기 때문에...
# 1      귀관이 구역질로 중대가를 연주할 실력이 된다면 모를까 그렇지 않은 바에야 작업 방해다
# 2     아ㅠ ㅠ ㅠ ㅋㅋㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 은하 그냥 눈치껏 그랬나 들어오세요 이러고 ...
# 3    형이랑 이러는 것도 이제 구역질나서 못해먹겠다 우리 그냥 각자 갈길 가요 다이아 반...
# 4    오늘 일반 돌리는데 상대팀 자꾸 저지 들고 게임 더럽게 하길래 우리팀은 오딘 들고 ...
# Name: tweet, dtype: object

# %%
DD['tweet'] = DD['tweet'].str.replace('^ +', "")
# Out:
# C:\Users\comet\AppData\Local\Temp\ipykernel_14516\2335845862.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   DD['tweet'] = DD['tweet'].str.replace('^ +', "")

# %%
DD['tweet'].replace('', np.nan, inplace=True)
print(DD['tweet'].isnull().sum())
# Out:
# 1

# %%
DD = DD.dropna(subset=['tweet'])

# %%
print(len(DD))
# Out:
# 7731

# %%
for val in DD['tweet']:
    check_1 = 0
    check_2 = 0
    check_3 = 0
    new_check_1 = 0
    new_check_2 = 0
    new_check_3 = 0
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        if tokens[i] in word_1:
            check_1 +=1
        elif tokens[i] in word_2:
            check_2 +=1
        elif tokens[i] in word_3:
            check_3 +=1
    for k in range(len(word_1)):
        new_check_1 += val.count(word_1[k])
    for j in range(len(word_2)):
        new_check_2 += val.count(word_2[j])
    for m in range(len(word_3)):
        new_check_3 += val.count(word_3[m])
        
    DD.loc[DD['tweet']==val, 'label1'] = check_1
    DD.loc[DD['tweet']==val, 'label2'] = check_2
    DD.loc[DD['tweet']==val, 'label3'] = check_3
    DD.loc[DD['tweet']==val, 'new_label1'] = new_check_1
    DD.loc[DD['tweet']==val, 'new_label2'] = new_check_2
    DD.loc[DD['tweet']==val, 'new_label3'] = new_check_3

# %%
print(DD[100:120])
# Out:
#                                                  tweet  label1  label2  \
# 100  으 징그럽사옵니다 정말로 소녀가 원하는 걸 모르셔서 그런 건 아니지 않사옵니까 고개...     0.0     0.0
# 101  뇨타는 인간이 감히 신에게 도전할 수 있는 가장 아름다운 행위이다 남성에게서 더럽고...     0.0     0.0
# 102  내 피는 오래됐고  더럽잖아 라는 말은 간신히 집어삼킨다 피묻은 거즈며 수술도구들이...     0.0     0.0
# 103  마몬 당신은 돈에 너무 집착합니다 모든 걸 돈으로 계산한다면 당신의 마음은 더럽고 ...     1.0     0.0
# 104  님이 그린 게이를 좋게 평가 하는게 아니야 나는 그냥 님이 그리는 남캐가 남자 다워...     1.0     1.0
# 105                                        바지에넣은거뭔가더럽다     0.0     0.0
# 106                             다른 그림들도 보면 뭔가 선선이더럽다       0.0     0.0
# 107  혼란스럽다 어수선하고 메리제인은 묘한 기시감을 느끼고 있었지만 애써 무시하고 있었다...     0.0     1.0
# 108                     저놈의 녀 호칭 저렇게나 못 잃는것도 대단하고 징그럽다     0.0     0.0
# 109  역경이야말로 우리 인간에게 무언가를 깨닫게 해준다 옴두꺼비처럼 흉측하고 독도 뿜어내...     0.0     0.0
# 110  그런거 아닙니다 귀찮다는듯 그를 툭툭 쳤다 목소리는 뭡니까 징그럽습니다 이상한 나르시스틱     0.0     0.0
# 111  안전팀장 정호라고합니다 기부터 존재해온 회사에서 제일 스탯 높은 친구 깐깐하고 날카...     0.0     0.0
# ...

# %%
DD.to_csv('./dDDb.csv', index=False, encoding="utf-8-sig")
